# %% [markdown]
# # GPT-3 vs GPT-2
# # (Language Models are Few-Shot Learners)
#
# Paper:
# - GPT-3 (2020)
# - Title:
#
# ```text
# Language Models are Few-Shot Learners
# ```
#
# Main idea:
#
# ```text
# Very large language models can perform new tasks
# from prompts alone with little or no fine-tuning.
# ```
#
# ---
#
# # Core Difference
#
# | GPT-2 | GPT-3 |
# |---|---|
# | smaller | massively larger |
# | weak few-shot ability | strong few-shot ability |
# | mostly generation | general in-context learning |
# | limited reasoning | much stronger reasoning |
# | 1.5B params | 175B params |
#
# ---
#
# # Parameter Size
#
# | Model | Parameters |
# |---|---|
# | GPT-2 Small | 117M |
# | GPT-2 XL | 1.5B |
# | GPT-3 | 175B |
#
# GPT-3 is:
#
# ```text
# 100x+ larger
# ```
#
# than GPT-2 XL.
#
# ---
#
# # Architecture
#
# Architecturally BOTH are:
#
# ```text
# decoder-only Transformer
# ```
#
# using:
# - causal masking
# - autoregressive next-token prediction
#
# ---
#
# # Training Objective
#
# Both train using:
#
# ```text
# predict next token
# ```
#
# Example:
#
# Input:
#
# ```text
# The sky is
# ```
#
# Target:
#
# ```text
# blue
# ```
#
# So:
#
# | GPT-2 | GPT-3 |
# |---|---|
# | self-supervised | self-supervised |
#
# ---
#
# # Biggest Innovation in GPT-3
#
# NOT architecture.
#
# Main innovation:
#
# ```text
# scaling
# ```
#
# GPT-3 showed:
#
# ```text
# large scale alone produces new abilities
# ```
#
# ---
#
# # GPT-2 Limitation
#
# GPT-2 could:
# - generate fluent text
# - continue prompts
#
# BUT struggled with:
# - task adaptation
# - reasoning
# - few-shot learning
#
# ---
#
# # GPT-3 Major Discovery
#
# GPT-3 can learn tasks directly from prompts.
#
# No gradient updates needed.
#
# ---
#
# # Example
#
# ## Translation
#
# Prompt:
#
# ```text
# English: cat
# French: chat
#
# English: dog
# French:
# ```
#
# GPT-3 predicts:
#
# ```text
# chien
# ```
#
# without fine-tuning.
#
# ---
#
# # Few-Shot Learning
#
# GPT-3 introduced strong:
#
# ```text
# in-context learning
# ```
#
# ---
#
# # Types of Learning
#
# ## Zero-shot
#
# Only instruction:
#
# ```text
# Translate English to French:
# dog →
# ```
#
# ---
#
# # One-shot
#
# One example:
#
# ```text
# cat → chat
# dog →
# ```
#
# ---
#
# # Few-shot
#
# Several examples inside prompt.
#
# ---
#
# # GPT-2 vs GPT-3 Few-Shot
#
# | Ability | GPT-2 | GPT-3 |
# |---|---|
# | zero-shot | weak | strong |
# | few-shot | weak | strong |
# | prompt learning | limited | powerful |
#
# ---
#
# # Why GPT-3 Improved
#
# Main reason:
#
# ```text
# scale
# ```
#
# More:
# - parameters
# - data
# - compute
#
# ---
#
# # Architecture Similarity
#
# | Feature | GPT-2 | GPT-3 |
# |---|---|
# | decoder-only | YES | YES |
# | causal attention | YES | YES |
# | autoregressive | YES | YES |
# | Transformer blocks | YES | YES |
#
# Very similar architecture.
#
# ---
#
# # GPT-3 New Capabilities
#
# Emergent abilities:
# - reasoning
# - translation
# - QA
# - summarization
# - arithmetic
# - code generation
#
# appeared at scale.
#
# ---
#
# # Important Paper Insight
#
# The paper discovered:
#
# ```text
# large language models can perform tasks
# without task-specific fine-tuning
# ```
#
# through prompting alone.
#
# ---
#
# # GPT-2 Era
#
# Usually required:
#
# ```text
# pretrain
# → fine-tune
# ```
#
# ---
#
# # GPT-3 Era
#
# Often possible:
#
# ```text
# pretrain
# → prompt only
# ```
#
# ---
#
# # Key Concept
#
# GPT-3 learns tasks:
#
# ```text
# inside the prompt context
# ```
#
# instead of:
# - changing weights
# - gradient updates
#
# ---
#
# # Big Picture
#
# ## GPT-2
#
# ```text
# Good text generator
# ```
#
# ---
#
# ## GPT-3
#
# ```text
# General-purpose in-context learner
# ```
#
# ---
#
# # Final Insight
#
# GPT-3 showed:
#
# ```text
# Scaling decoder-only language models
# creates powerful few-shot learning abilities
# without changing architecture significantly.
# ```

# %% [markdown]
# # GPT-2 vs GPT-3 Architecture Difference
#
# Surprisingly:
#
# ```text
# GPT-2 and GPT-3 use almost the SAME architecture.
# ```
#
# Both are:
#
# ```text
# decoder-only Transformer
# ```
#
# using:
# - causal self-attention
# - autoregressive next-token prediction
#
# ---
#
# # Core Architecture
#
# Both use:
#
# ```text
# Input Tokens
#       ↓
# Token Embeddings
#       ↓
# Masked Self-Attention
#       ↓
# Feedforward Layers
#       ↓
# Next Token Prediction
# ```
#
# ---
#
# # Main Difference
#
# The BIGGEST difference is:
#
# ```text
# SCALE
# ```
#
# NOT a fundamentally new architecture.
#
# ---
#
# # Architecture Comparison
#
# | Feature | GPT-2 | GPT-3 |
# |---|---|
# | Transformer type | decoder-only | decoder-only |
# | Attention | causal self-attention | causal self-attention |
# | Positional embeddings | learned absolute | learned absolute |
# | Objective | next-token prediction | next-token prediction |
# | Feedforward blocks | yes | yes |
# | Residual connections | yes | yes |
# | LayerNorm | yes | yes |
#
# Very similar architecture.
#
# ---
#
# # Major Scaling Differences
#
# | Component | GPT-2 | GPT-3 |
# |---|---|
# | Parameters | 1.5B | 175B |
# | Layers | 48 | 96 |
# | Hidden size | 1600 | 12288 |
# | Attention heads | 25 | 96 |
# | Context length | 1024 | 2048 |
# | Training data | smaller | much larger |
#
# ---
#
# # GPT-2 Architecture
#
# Simplified:
#
# ```text
# Embedding
#    ↓
# 48 Transformer decoder blocks
#    ↓
# Linear output layer
# ```
#
# ---
#
# # GPT-3 Architecture
#
# Simplified:
#
# ```text
# Embedding
#    ↓
# 96 larger Transformer decoder blocks
#    ↓
# Linear output layer
# ```
#
# ---
#
# # Attention Mechanism
#
# Both use:
#
# ```text
# causal masking
# ```
#
# Meaning:
#
# ```text
# token can only attend to previous tokens
# ```
#
# NOT future tokens.
#
# ---
#
# # Attention Formula
#
# Both use:
#
# :contentReference[oaicite:0]{index=0}
#
# ---
#
# # Position Embedding
#
# Both use:
#
# ```text
# learned absolute positional embeddings
# ```
#
# Unlike:
# - T5 relative bias
#
# ---
#
# # Decoder-Only
#
# Neither GPT-2 nor GPT-3 has:
# - encoder
# - encoder-decoder cross attention
#
# Only:
# - decoder stack
#
# ---
#
# # Why GPT-3 Became Much Better
#
# Mainly because of:
#
# ```text
# more scale
# ```
#
# Specifically:
# - more parameters
# - more data
# - longer training
# - larger context window
#
# ---
#
# # Emergent Abilities
#
# GPT-3 discovered:
#
# ```text
# large enough decoder-only Transformers
# develop few-shot learning abilities
# ```
#
# without architecture change.
#
# ---
#
# # Important Insight
#
# GPT-3 was NOT a major architecture innovation.
#
# The innovation was:
#
# ```text
# scaling Transformer language models massively
# ```
#
# ---
#
# # Simplified View
#
# ## GPT-2
#
# ```text
# Smaller decoder-only Transformer
# ```
#
# ---
#
# ## GPT-3
#
# ```text
# Much larger decoder-only Transformer
# ```
#
# with same core design.
#
# ---
#
# # Final Insight
#
# Architecturally:
#
# ```text
# GPT-2 ≈ GPT-3
# ```
#
# The revolutionary difference was:
#
# ```text
# massive scaling produced emergent capabilities
# ```
#
# like:
# - few-shot learning
# - reasoning
# - in-context learning.
